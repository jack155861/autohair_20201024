# %%
from combine import auto_hair

# %%
resized_im, mask, trimap_im, final, deeplablv3_final = auto_hair('06.jpg', 20, 5)

# %%
final
# Out:
# <PIL.Image.Image image mode=RGBA size=384x513 at 0x7FD96055D110>

# %%
final
# Out:
# <PIL.Image.Image image mode=RGBA size=384x513 at 0x7FD960579310>
